# %%
import os
from keras.applications.inception_v3 import preprocess_input
from keras.models import Model, load_model
from keras.preprocessing import image
import numpy as np
from IPython.display import Image, display
# Out:
# Using TensorFlow backend.

# %%
# Suppress warning and informational messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
inputDir = "test"
clasificationList =['Daisy','Dandelion']

# %%
new_model = load_model('inceptionv3-fine-tune.h5')

# %%
for root, dirs, files in os.walk(inputDir):
   for filename in files:

       img = image.load_img(inputDir+'/'+filename, target_size=(299, 299))
       x = image.img_to_array(img)
       x = np.expand_dims(x, axis = 0)
       x = preprocess_input(x)
       
       features = new_model.predict(x)
       print('****************************************')
       print(" ")
       print('Processing file : '+ filename)
       print('Here are the weights [[Daisy Dandelion]] : ',features)
       display(Image(filename=inputDir+'/'+filename))
       if features[0][0] > features[0][1] :
           print('Input image clasification is : '+clasificationList[0])
       else:
           print('Input image clasification is : '+clasificationList[1])
       print(" ")

print('****************************************')
# Out:
# ****************************************
#
# Processing file : 1.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9982843  0.00171571]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : 10.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.02153634 0.9784637 ]]
# Input image clasification is : Dandelion
#
# ****************************************
#
# Processing file : 2.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9984459  0.00155411]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : 3.jpg
# Here are the weights [[Daisy Dandelion]] :  [[9.9970406e-01 2.9595854e-04]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : 4.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9988288  0.00117113]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : 5.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.99313897 0.00686099]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : 6.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.05744619 0.94255376]]
# Input image clasification is : Dandelion
#
# ****************************************
#
# Processing file : 7.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.08534817 0.9146519 ]]
# Input image clasification is : Dandelion
#
# ****************************************
#
# Processing file : 8.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9797956  0.02020445]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : 9.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9988595  0.00114051]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : Daisy1.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9982843  0.00171571]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : Daisy2.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9984459  0.00155411]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : Daisy3.jpg
# Here are the weights [[Daisy Dandelion]] :  [[9.9970406e-01 2.9595854e-04]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : Daisy4.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.9988288  0.00117113]]
# Input image clasification is : Daisy
#
# ****************************************
#
# Processing file : Daisy5.jpg
# Here are the weights [[Daisy Dandelion]] :  [[0.99313897 0.00686099]]
# Input image clasification is : Daisy
